# %% [markdown]
# ### TYPE YOUR NAME HERE: Anna G. Castillo

# %% [markdown]
# # ISM 5644 - Programming for Analytics
#
# ## Lab Exercise: Error Handling

# %% [markdown]
# ### Overview:
# This lab covers operations related to errors and exceptions.

# %% [markdown]
# ### Task:
# The code cells in this notebook have been left blank. Your task is to complete these cells and provide the execution results. The corresponding question text for each code cell is provided above the cell.
#
# ### Important: Do <u>not</u> forget to run the cells before submitting your work.

# %% [markdown]
# ### Questions:

# %% [markdown]
# #### 1. Initialize the following list: a_list = [4, 3, 'number', 1, 0]. First, write a simple for loop that increments each element in this list by 3 and prints out the results. Notice the error message you receive. Now, add a try-except construct to this loop that catches the specific exception type, prints "not proper type for arithmetic operations", and allows the loop to continue.
# Note: You only need to print out the results, do not modify the original list.

# %%
a_list = [4, 3, 'number', 1, 0]

for item in a_list:
    try:
        print(item + 3)
    except TypeError:
        print("not proper type for arithmetic operations")
# Out:
# 7
# 6
# not proper type for arithmetic operations
# 4
# 3

# %% [markdown]
# #### 2. Consider the integer x = 5. Write a While loop that prompts the user via input() to enter a divisor and divides x by the input. The loop should stop the results of the division is successfully printed. Otherwise, it should keep prompting the user for a new input. Also, your program must use an EAFP (try-except) approach to handle two distinct potential failure modes:
# 1. The user inputs text that cannot be converted into an integer (e.g., typing "two" or "3.5"), throwing a ValueError.
# 2. The user inputs 0, throwing a ZeroDivisionError.
#
# If an exception occurs, print a unique, descriptive error message for that specific error type.

# %%
x = 5
while True:
    try:
        divisor_input = input("Enter a divisor: ")
        divisor = int(divisor_input)
        result = x / divisor
        print('Result of', x, '/', divisor, '=', result)
        break 
    except ValueError:
        print("ValueError: Input must be a valid integer.")
    except ZeroDivisionError:
        print("ZeroDivisionError: Division by zero is not allowed. Enter a non-zero number.")
# Out:
# Enter a divisor:  0
# ZeroDivisionError: Division by zero is not allowed. Enter a non-zero number.
# Enter a divisor:  3.4
# ValueError: Input must be a valid integer.
# Enter a divisor:  4
# Result of 5 / 4 = 1.25

# %% [markdown]
# #### 3. Consider a dictionary lookup loop where we'd like to retrieve the value of a key from the data dictionary. Write a for loop that iterates through keys_to_check and prints out the corresponding value from data. To handle errors gracefully, implement a try-except block inside the loop and catch the base exception using the dynamic alias syntax: except Exception as exc. Inside the exception block, print both the type of the error and the value that caused it.
# ```python
# keys_to_check = ["apple", "blueberry", "banana", [1, 2], "cherry"]
# data = {"apple": 5, "banana": 3, "cherry": 7}
# ```

# %%
keys_to_check = ["apple", "blueberry", "banana", [1, 2], "cherry"]
data = {"apple": 5, "banana": 3, "cherry": 7}

for key in keys_to_check:
    try:
        print(data[key])
    except Exception as exc:
        print("Error type:", type(exc),'.', "Caused by key/value:", key)
# Out:
# 5
# Error type: <class 'KeyError'> . Caused by key/value: blueberry
# 3
# Error type: <class 'TypeError'> . Caused by key/value: [1, 2]
# 7

# %% [markdown]
# #### 4. Follow the steps below to develop a program that utilizes multiple try-except blocks to handle file interactions and math errors:
#
# Try to open a file called "someNumbers.txt" in read mode ('r').
#
# Because the file does not exist yet, a FileNotFoundError will occur. Catch this specific exception using an except block. Inside this block, create the file, write the numbers from aList = [10, 50, 0, 20, 40] into it (each on a new line), and ensure the file is closed. Run your code once so the file is generated.
#
# Next, open the successfully created file. Iterate through it line by line.
#
# Inside the loop, attempt to divide the integer 10 by the value from the file. Because file contents are read as strings, this will cause an error. Design your try-except structure to catch this type mismatch, convert the string to an integer, and attempt the division again.
#
# One of the values in the file is 0, which will introduce a second type of error during division. Add handling to catch this specific error so the program skips it silently using continue.
#
# Close your file at the end of execution.

# %%
aList = [10, 50, 0, 20, 40]
try:
    file = open("someNumbers.txt", "r")
except FileNotFoundError:
    file = open("someNumbers.txt", "w")
    for num in aList:
        file.write(str(num) + "\n")
    file.close()
    file = open("someNumbers.txt", "r")

for line in file:
    val_str = line.strip()
    try:
        result = 10 / val_str
        print(result)
    except TypeError:
        try:
            val_int = int(val_str)
            result = 10 / val_int
            print(f"10 / {val_int} = {result}")
        except ZeroDivisionError:
            continue

file.close()
# Out:
# 10 / 10 = 1.0
# 10 / 50 = 0.2
# 10 / 20 = 0.5
# 10 / 40 = 0.25

# %% [markdown]
# #### 5. The following function is intended to take a list of data column headers, clean them up (remove leading/trailing whitespace, lowercase them, and replace spaces with underscores), and return the cleaned list. However, the function contains a design error—when called, it returns the list unchanged.
# ```python
# def clean_headers(header_list):
#     for header in header_list:
#         header = header.strip().lower().replace(" ", "_")
#     return header_list
# ```
#
# Write a corrected version of the clean_headers function. Inside your function's loop, include a print() statement as a debugging probe to show that you inspected how the data updates at each iteration. Test your completed function using the test list provided below to verify it outputs the correct results.
# ```python
# test_list = ["  User ID  ", "First Name", "Transaction_Amount  "]
# ```

# %%
def clean_headers(header_list):
    cleaned_list = []
    for header in header_list:
        cleaned = header.strip().lower().replace(" ", "_")
        print('Original header:', header,'-','Cleaned header:', cleaned)
        cleaned_list.append(cleaned)
    return cleaned_list

test_list = ["  User ID  ", "First Name", "Transaction_Amount  "]
result = clean_headers(test_list)
print("Final Output:", result)
# Out:
# Original header:   User ID   - Cleaned header: user_id
# Original header: First Name - Cleaned header: first_name
# Original header: Transaction_Amount   - Cleaned header: transaction_amount
# Final Output: ['user_id', 'first_name', 'transaction_amount']

# %% [markdown]
# #### 6. Below is a median function implementation that intends to find the median value of a given list. There are multiple syntax, runtime, and logical errors in this program (pay close attention to how indices are calculated and used). Identify and fix these errors. Test your corrected function with both odd-length and even-length lists to verify its execution.
# ```python
# def median(L):
#     L_length = len(L)
#     L_sorted = sorted(L)
#     if L_length%2 = 1:
#         return L_sorted[L_length/2]
#     else:
#         return (L_sorted[L_length/2] + L_sorted[L_length/2 + 1])/2
# ```

# %%
def median(L):
    L_length = len(L)
    L_sorted = sorted(L)
    
    if L_length % 2 == 1:
        return L_sorted[L_length // 2]
    else:
        mid = L_length // 2
        return (L_sorted[mid - 1] + L_sorted[mid]) / 2

odd_list = [7, 1, 3, 9, 5]
print("Median of odd-length list:", median(odd_list))

even_list = [7, 1, 3, 9, 5, 11]
print("Median of even-length list:", median(even_list))
# Out:
# Median of odd-length list: 5
# Median of even-length list: 6.0
